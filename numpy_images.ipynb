# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
pic=Image.open('avengers2.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=590x350 at 0x21C2A033CC0>

# %%
pic_array=np.asarray(pic)

# %%
pic_array
# Out:
# array([[[ 1,  1,  1],
#         [ 1,  1,  1],
#         [ 2,  2,  2],
#         ...,
#         [ 5,  3,  8],
#         [ 5,  3,  8],
#         [ 5,  3,  8]],
#
#        [[ 1,  1,  1],
#         [ 1,  1,  1],
#         [ 2,  2,  2],
#         ...,
#         [ 4,  2,  7],
#         [ 4,  2,  7],
#         [ 4,  2,  7]],
#
#        [[ 1,  1,  1],
#         [ 1,  1,  1],
#         [ 2,  2,  2],
#         ...,
#         [ 4,  2,  7],
#         [ 4,  2,  7],
#         [ 4,  2,  7]],
#
#        ...,
#
#        [[29, 13, 26],
#         [28, 12, 25],
#         [27, 11, 24],
#         ...,
#         [40, 11, 15],
#         [40, 11, 15],
#         [39, 10, 14]],
#
#        [[26, 10, 21],
#         [24,  8, 19],
#         [23,  7, 18],
#         ...,
#         [40, 11, 15],
#         [40, 11, 15],
#         [40, 11, 15]],
#
#        [[19,  6, 16],
#         [16,  3, 13],
#         [15,  2, 12],
#         ...,
#         [40, 11, 15],
#         [41, 12, 16],
#         [41, 12, 16]]], dtype=uint8)

# %%
pic_array.shape
# Out:
# (350, 590, 3)

# %%
plt.imshow(pic_array)

# %%
pic_red = pic_array.copy()

# %%
pic_red[:, :, 1] = 0    # Zero out contribution from green
pic_red[:, :, 2] = 0    # Zero out contribution from blue

# %%
plt.imshow(pic_red)
